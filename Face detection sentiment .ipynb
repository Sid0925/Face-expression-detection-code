# %%
import cv2
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
 
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.models import load_model
face_cascade = cv2.CascadeClassifier('C:\\Users\\Siddharth\\Desktop\\face expreassion project\\haarcascade-frontalface-default.xml')
model = load_model('C:\\Users\\Siddharth\\Desktop\\face expreassion project\\sample.h5')

# %%
labels_dict={'happy':'smile','sad':'No smile'}
color_dict={0:(0,255,0),1:(0,0,255)}

# %%
import cv2
#import mediapipe as mp
import time
cap = cv2.VideoCapture('C:\\Users\\Siddharth\\Downloads\\wel.mp4') # video path 'C:\\Users\\Siddharth\\Downloads\\friends.mp4'
pTime = 0
while True:
    
    succ ,img = cap.read()
    gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray,1.5,5)
    
    for (x, y, w, h) in faces:
        #Data preprocessing
        face_img = gray[y:y+h,x:x+w]
        #print(face_img)
        resized = cv2.resize(face_img,(48,48))
        normalize = resized/255.0
        reshaped = np.reshape(normalize,(1,48,48,1))
        result = model.predict(reshaped)
        #print(face_img)
        label = ''
        if result > 0.5:
            label = 'sad'
        elif result < 0.5:
            label= 'happy'
        
         
        #print(result)
         
        
        cv2.rectangle(img,(x,y),(x+w,y+h),(0, 255, 0),2) 
        cv2.putText(img,  labels_dict[label] ,(x, y-10),cv2.FONT_HERSHEY_PLAIN,2,(0, 255, 0),2)
            
    
            
            
    cv2.imshow('LIVE',img)
    key=cv2.waitKey(1)
    
    if cv2.waitKey(100)== ord('q'):
        break
        
cv2.destroyAllWindows()
source.release()
# Out:
# ...
# 1/1 [==============================] - 0s 16ms/step
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 44>()
#      41         break
#      43 cv2.destroyAllWindows()
# ---> 44 source.release()
#
# NameError: name 'source' is not defined
